# %% [markdown]
# # Converting Addresses Function

# %%
import pandas as pd
import numpy as np
from pygeocoder import Geocoder

# %%
#was used to create new csv with lat and lon columns

"""
df_temp = pd.read_csv('Datasets/pd_collisions_datasd_v1.csv')
df_temp.shape
df_temp['lat'] = [np.nan for x in range(28595)]
df_temp['lon'] = [np.nan for x in range(28595)]
df_temp.to_csv('collisions_with_coords.csv')
"""
# Out:
# "\ndf_temp = pd.read_csv('Datasets/pd_collisions_datasd_v1.csv')\ndf_temp.shape\ndf_temp['lat'] = [np.nan for x in range(28595)]\ndf_temp['lon'] = [np.nan for x in range(28595)]\ndf_temp.to_csv('collisions_with_coords.csv')\n"

# %%
df = pd.read_csv('collisions_with_coords.csv')
addresses = df.apply(lambda x : ' '.join(
    str(i).strip() for i in [x.address_number_primary, x.address_pd_primary, x.address_road_primary, x.address_sfx_primary] 
) + ', SAN DIEGO', axis = 1)

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1 report_id            date_time  police_beat  \
# 0               0             0    170082  2017-01-01 00:01:00          935
# 1               1             1    170101  2017-01-01 00:01:00          322
# 2               2             2    170166  2017-01-01 00:01:00          124
# 3               3             3    170218  2017-01-01 00:01:00          325
# 4               4             4    170097  2017-01-01 01:00:00          521
# 5               5             5    170220  2017-01-01 01:00:00          524
# 6               6             6    170153  2017-01-01 01:18:00          437
# 7               7             7    170035  2017-01-01 01:53:00          935
# 8               8             8    170044  2017-01-01 01:58:00          115
# 9               9             9    170042  2017-01-01 02:00:00          122
# 10             10            10    170041  2017-01-01 02:00:00          122
# ...

# %%
MAPS_API_KEY = 'AIzaSyA1RfIMA8m6U5-pygR8-_EECoTe3C8Y7xc'
coder = Geocoder(MAPS_API_KEY)

CRASHES_START = 3500
CRASHES_END = 4500

#locations = addresses[CRASHES_START:CRASHES_END].apply(lambda address : coder.geocode(address).coordinates)


for x in range(CRASHES_START, CRASHES_END):
    locations = addresses[x:x+1].apply(lambda address : coder.geocode(address).coordinates)
    df.at[x,'lat'] = locations[x][0]
    df.at[x,'lon'] = locations[x][1]

# %%
#Show which indecies have no lat-lon pairs yet
df['lat'].isnull()[df['lat'].isnull()]
# Out:
# 4392     True
# 4500     True
# 4501     True
# 4502     True
# 4503     True
# 4504     True
# 4505     True
# 4506     True
# 4507     True
# 4508     True
# 4509     True
# 4510     True
# 4511     True
# 4512     True
# 4513     True
# 4514     True
# 4515     True
# 4516     True
# 4517     True
# 4518     True
# 4519     True
# 4520     True
# 4521     True
# 4522     True
# 4523     True
# 4524     True
# 4525     True
# 4526     True
# 4527     True
# 4528     True
#          ...
# 28565    True
# 28566    True
# 28567    True
# 28568    True
# 28569    True
# 28570    True
# 28571    True
# 28572    True
# 28573    True
# 28574    True
# 28575    True
# 28576    True
# 28577    True
# 28578    True
# 28579    True
# 28580    True
# 28581    True
# 28582    True
# 28583    True
# 28584    True
# 28585    True
# 28586    True
# 28587    True
# 28588    True
# 28589    True
# 28590    True
# 28591    True
# 28592    True
# 28593    True
# 28594    True
# ...

# %%
#DONT FORGET TO SAVE TO CSV FILE

df.to_csv('collisions_with_coords.csv')

# %%
#converting the converted addresses to tuple and adding them to a new dataframe with 
# their respective addresses

df_locations = df
df_locations['Address']=addresses

df_locations['Coordinates'] = [(0,0) for x in range (len(addresses))]

for x in range(len(addresses)):
    df_locations.at[x, 'Coordinates'] = df.at[x, 'lat'], df.at[x, 'lon']

# %%
df_locations = df_locations.loc[:CRASHES_END-1,['Address', 'Coordinates']]
df_locations
# Out:
#                                          Address  \
# 0                 5500  VALERIO TRAIL, SAN DIEGO
# 1               6400  CRAWFORD STREET, SAN DIEGO
# 2                  8300  CAM DEL ORO , SAN DIEGO
# 3             8100  ROYAL GORGE DRIVE, SAN DIEGO
# 4                   1000  11TH AVENUE, SAN DIEGO
# 5                      1000  A STREET, SAN DIEGO
# 6                  2600  RAMFOS PLACE, SAN DIEGO
# 7                  3900  DE LA VALLE , SAN DIEGO
# 8                  9100  SYDNEY COURT, SAN DIEGO
# 9              1600  HORNBLEND STREET, SAN DIEGO
# 10                900  EMERALD STREET, SAN DIEGO
# 11                 0  IMPERIAL AVENUE, SAN DIEGO
# 12                2900  LAUREL STREET, SAN DIEGO
# 13              10000  BLACK MTN ROAD, SAN DIEGO
# 14            5800  UNIVERSITY AVENUE, SAN DIEGO
# 15                 6900  MIRAMAR ROAD, SAN DIEGO
# 16              2500  INGRAHAM STREET, SAN DIEGO
# 17           2400 W MISSION BAY DRIVE, SAN DIEGO
# ...

# %%
#saving the rows with converted addresses to the locations csv

df_locations.to_csv('Datasets/locations.csv')
