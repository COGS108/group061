# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import datetime, nltk, warnings
import matplotlib.cm as cm
import itertools
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn import preprocessing, model_selection, metrics, feature_selection
from sklearn.model_selection import GridSearchCV, learning_curve
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn import neighbors, linear_model, svm, tree, ensemble
from wordcloud import WordCloud, STOPWORDS
from sklearn.ensemble import AdaBoostClassifier
from sklearn.decomposition import PCA
from IPython.display import display, HTML
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ParkerJiang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/ParkerJiang/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df_initial = pd.read_csv('pd_collisions_datasd_v1.csv')

# %%
df_initial.head()
# Out:
#   report_id            date_time  police_beat  address_number_primary  \
# 0    170082  2017-01-01 00:01:00          935                    5500
# 1    170101  2017-01-01 00:01:00          322                    6400
# 2    170166  2017-01-01 00:01:00          124                    8300
# 3    170218  2017-01-01 00:01:00          325                    8100
# 4    170097  2017-01-01 01:00:00          521                    1000
#
#   address_pd_primary address_road_primary address_sfx_primary  \
# 0                                 VALERIO               TRAIL
# 1                                CRAWFORD              STREET
# 2                             CAM DEL ORO
# 3                             ROYAL GORGE               DRIVE
# 4                                    11TH              AVENUE
#
#   address_pd_intersecting address_name_intersecting address_sfx_intersecting  \
# 0
# 1
# 2
# 3
# 4
#
#   violation_section violation_type  \
# 0          MISC-HAZ             VC
# 1          MISC-HAZ             VC
# 2          MISC-HAZ             VC
# 3             22107             VC
# 4             22107             VC
#
#                                          charge_desc  injured  killed  \
# 0  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 1  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 2  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# 3             TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
# 4             TURNING MOVEMENTS AND REQUIRED SIGNALS        0       0
#
#    hit_run_lvl
# 0  MISDEMEANOR
# 1  MISDEMEANOR
# 2  MISDEMEANOR
# 3  MISDEMEANOR
# 4  MISDEMEANOR

# %%
print('Dataframe dimensions:', df_initial.shape)
# Out:
# Dataframe dimensions: (28595, 16)

# %%
tab_info=pd.DataFrame(df_initial.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df_initial.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df_initial.isnull().sum()/df_initial.shape[0]*100).T.
                         rename(index={0:'null values (%)'}))

# %%
display(tab_info)
# Out:
#                  report_id date_time police_beat address_number_primary  \
# column type         object    object       int64                  int64
# null values (nb)         0         0           0                      0
# null values (%)          0         0           0                      0
#
#                  address_pd_primary address_road_primary address_sfx_primary  \
# column type                  object               object              object
# null values (nb)                  0                    0                   4
# null values (%)                   0                    0           0.0139885
#
#                  address_pd_intersecting address_name_intersecting  \
# column type                       object                    object
# null values (nb)                       0                         0
# null values (%)                        0                         0
#
#                  address_sfx_intersecting violation_section violation_type  \
# column type                        object            object         object
# null values (nb)                       10                 0              0
# null values (%)                 0.0349711                 0              0
#
#                  charge_desc injured killed hit_run_lvl
# column type           object   int64  int64      object
# null values (nb)           0       0      0       15267
# null values (%)            0       0      0     53.3905

# %%
df_initial.hit_run_lvl.unique()
# Out:
# array(['MISDEMEANOR', nan, 'FELONY'], dtype=object)

# %%
from pygeocoder import Geocoder

# %%
result = Geocoder.geocode("5500 VALERIO TRAIL, San Diego").valid_address
# Out:
# ---------------------------------------------------------------------------
# GeocoderError                             Traceback (most recent call last)
# <ipython-input-10-208a00feab2d> in <module>
# ----> 1 result = Geocoder.geocode("5500 VALERIO TRAIL, San Diego").valid_address
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pygeocoder.py in geocode(self, address, sensor, bounds, region, language, components)
#     127             return GeocoderResult(self.get_data(params=params))
#     128         else:
# --> 129             return GeocoderResult(Geocoder.get_data(params=params))
#     130
#     131     @omnimethod
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pygeocoder.py in get_data(self, params)
#     210
#     211         if response_json['status'] != GeocoderError.G_GEO_OK:
# --> 212             raise GeocoderError(response_json['status'], response.url)
#     213         return response_json['results']
#     214
#
# GeocoderError: Error REQUEST_DENIED
# Query: https://maps.google.com/maps/api/geocode/json?address=5500+VALERIO+TRAIL%2C+San+Diego&sensor=false&bounds=&region=&language=&components=
